# %%
import pandas as pd
import json
from platform import python_version

# %%
print(python_version())
print(pd.__version__)
# Out:
# 3.10.10
# 2.1.1

# %%
import os

# %%
current_directory = os.getcwd()

# %%
files_and_directories = os.listdir('/home/rodrigo/repos/DATAVIZ_project/')

# %%
print("Current Directory:", current_directory)
print("files and directories:", files_and_directories)
# Out:
# Current Directory: /home/rodrigo/repos/DATAVIZ_project/dataviz_venv/jupyter_notebooks
# files and directories: ['README.md', '.git', 'BIOPRO_G.csv', 'dataviz_venv']

# %%
df = pd.read_csv('/home/rodrigo/repos/DATAVIZ_project/BIOPRO_G.csv')

# %%
# get the first five rows of the dataframe
df.head()
# Out:
#    Unnamed: 0   seqn  lbxsal  lbdsalsi  lbxsatsi  lbxsassi  lbxsapsi  lbxsbu  \
# 0           1  62161     4.8      48.0      19.0      25.0      89.0    14.0
# 1           2  62163     4.0      40.0      13.0      19.0     167.0    16.0
# 2           3  62164     3.7      37.0      29.0      37.0      23.0     5.0
# 3           4  62165     4.1      41.0      13.0      19.0      94.0    12.0
# 4           5  62169     4.4      44.0      19.0      17.0      51.0    16.0
#
#    lbdsbusi  lbxsca  ...  lbxsua  lbdsuasi  lbxsnasi  lbxsksi  lbxsclsi  \
# 0      5.00     9.6  ...     4.9     291.5     137.0      3.9     100.0
# 1      5.71     9.1  ...     5.8     345.0     137.0      3.8     104.0
# 2      1.79     9.2  ...     4.5     267.7     138.0      4.3     104.0
# 3      4.28     9.7  ...     5.8     345.0     139.0      4.0     105.0
# 4      5.71     9.2  ...     5.4     321.2     139.0      4.4     103.0
#
#    lbxsossi  lbxsgb  lbdsgbsi  lbxstr  lbdstrsi
# ...

# %%
a = df.iloc[0:, 2:]  # slicing only the values without id and seqn

# %%
a
# Out:
#       lbxsal  lbdsalsi  lbxsatsi  lbxsassi  lbxsapsi  lbxsbu  lbdsbusi  \
# 0        4.8      48.0      19.0      25.0      89.0    14.0      5.00
# 1        4.0      40.0      13.0      19.0     167.0    16.0      5.71
# 2        3.7      37.0      29.0      37.0      23.0     5.0      1.79
# 3        4.1      41.0      13.0      19.0      94.0    12.0      4.28
# 4        4.4      44.0      19.0      17.0      51.0    16.0      5.71
# ...      ...       ...       ...       ...       ...     ...       ...
# 6544     4.8      48.0      20.0      19.0      52.0    15.0      5.36
# 6545     4.1      41.0      38.0      26.0      92.0    11.0      3.93
# 6546     4.7      47.0      28.0      29.0      65.0     7.0      2.50
# 6547     4.2      42.0      22.0      21.0      77.0    11.0      3.93
# 6548     NaN       NaN       NaN       NaN       NaN     NaN       NaN
#
#       lbxsca  lbdscasi  lbxsck  ...  lbxsua  lbdsuasi  lbxsnasi  lbxsksi  \
# ...

# %%
a.describe()
# Out:
#             lbxsal     lbdsalsi     lbxsatsi     lbxsassi     lbxsapsi  \
# count  5976.000000  5976.000000  5972.000000  5969.000000  5974.000000
# mean      4.306861    43.068608    23.701105    25.325515    79.868597
# std       0.343757     3.437569    24.637657    15.955600    52.831267
# min       2.100000    21.000000     5.000000     7.000000     7.000000
# 25%       4.100000    41.000000    15.000000    19.000000    54.000000
# 50%       4.300000    43.000000    19.000000    23.000000    66.000000
# 75%       4.500000    45.000000    26.000000    27.000000    85.000000
# max       5.500000    55.000000  1363.000000   597.000000   729.000000
#
#             lbxsbu     lbdsbusi       lbxsca     lbdscasi       lbxsck  ...  \
# count  5975.000000  5975.000000  5974.000000  5974.000000  5968.000000  ...
# mean     12.514979     4.468231     9.418296     2.354574   161.897118  ...
# std       5.454846     1.947445     0.356370     0.089093   180.982757  ...
# ...

# %%
# Create a dictionary to map the code column names to their actual names
column_mapping = {
    "lbxsal": "Albumin (g/dL)",
    "lbdsalsi": "Albumin (g/L)",
    "lbxsatsi": "Alanine aminotransferase ALT (U/L)",
    "lbxsassi": "Aspartate aminotransferase AST (U/L)",
    "lbxsapsi": "Alkaline phosphatase (U/L)",
    "lbxsbu": "Blood urea nitrogen (mg/dL)",
    "lbdsbusi": "Blood urea nitrogen (mmol/L)",
    "lbxsca": "Total calcium (mg/dL)",
    "lbdscasi": "Total calcium (mmol/L)",
    "lbxsck": "Creatine Phosphokinase (CPK) (IU/L)",
    "lbxsch": "Cholesterol (mg/dL)",
    "lbdschsi": "Cholesterol (mmol/L)",
    "lbxsc3si": "Bicarbonate (mmol/L)",
    "lbxscr": "Creatinine (mg/dL)",
    "lbdscrsi": "Creatinine (umol/L)",
    "lbxsgtsi": "Gamma glutamyl transferase (U/L)",
    "lbxsgl": "Glucose, serum (mg/dL)",
    "lbdsglsi": "Glucose, serum (mmol/L)",
    "lbxsir": "Iron, refrigerated (ug/dL)",
    "lbdsirsi": "Iron, refrigerated (umol/L)",
    "lbxslidsi": "Lactate dehydrogenase (U/L)",
    "lbxsph": "Phosphorus (mg/dL)",
    "lbdspohsi": "Phosphorus (mmol/L)",
    "lbxstb": "Total bilirubin (mg/dL)",
    "lbdstbsi": "Total bilirubin (umol/L)",
    "lbxstp": "Total protein (g/dL)",
    "lbdstpsi": "Total protein (g/L)",
    "lbxsua": "Uric acid (mg/dL)",
    "lbdsuasi": "Uric acid (umol/L)",
    "lbxsnasi": "Sodium (mmol/L)",
    "lbxksi": "Potassium (mmol/L)",
    "lbxsclsi": "Chloride (mmol/L)",
    "lbxsossi": "Osmolality (mmol/Kg)",
    "lbxsbg": "Globulin (g/dL)",
    "lbdsgbsi": "Globulin (g/L)",
    "lbxstr": "Triglycerides (mg/dL)",
    "lbdstrsi": "Triglycerides (mmol/L)"
}



# Rename the columns using the mapping dictionary
renamed_df = a.rename(columns=column_mapping)

# Display the updated DataFrame
renamed_df
# Out:
#       Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0                4.8           48.0                                19.0
# 1                4.0           40.0                                13.0
# 2                3.7           37.0                                29.0
# 3                4.1           41.0                                13.0
# 4                4.4           44.0                                19.0
# ...              ...            ...                                 ...
# 6544             4.8           48.0                                20.0
# 6545             4.1           41.0                                38.0
# 6546             4.7           47.0                                28.0
# 6547             4.2           42.0                                22.0
# 6548             NaN            NaN                                 NaN
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# ...

# %%
# check if all columns got their name changed
column_list = renamed_df.columns.tolist()

# Display the list of column names
print(column_list)
# Out:
# ['Albumin (g/dL)', 'Albumin (g/L)', 'Alanine aminotransferase ALT (U/L)', 'Aspartate aminotransferase AST (U/L)', 'Alkaline phosphatase (U/L)', 'Blood urea nitrogen (mg/dL)', 'Blood urea nitrogen (mmol/L)', 'Total calcium (mg/dL)', 'Total calcium (mmol/L)', 'Creatine Phosphokinase (CPK) (IU/L)', 'Cholesterol (mg/dL)', 'Cholesterol (mmol/L)', 'Bicarbonate (mmol/L)', 'Creatinine (mg/dL)', 'Creatinine (umol/L)', 'Gamma glutamyl transferase (U/L)', 'Glucose, serum (mg/dL)', 'Glucose, serum (mmol/L)', 'Iron, refrigerated (ug/dL)', 'Iron, refrigerated (umol/L)', 'lbxsldsi', 'Phosphorus (mg/dL)', 'lbdsphsi', 'Total bilirubin (mg/dL)', 'Total bilirubin (umol/L)', 'Total protein (g/dL)', 'Total protein (g/L)', 'Uric acid (mg/dL)', 'Uric acid (umol/L)', 'Sodium (mmol/L)', 'lbxsksi', 'Chloride (mmol/L)', 'Osmolality (mmol/Kg)', 'lbxsgb', 'Globulin (g/L)', 'Triglycerides (mg/dL)', 'Triglycerides (mmol/L)']

# %%
#renaming missing columns
renamed_df.rename(columns={
    'lbxsldsi': 'Lactate Dehydrogenase (U/L)',
    'lbdsphsi': 'Phosphorus (mmol/L)',
    'lbxsksi': 'Potassium (mmol/L)',
    'lbxsgb': 'Globulin (g/dL)'
}, inplace=True)

renamed_df
# Out:
#       Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0                4.8           48.0                                19.0
# 1                4.0           40.0                                13.0
# 2                3.7           37.0                                29.0
# 3                4.1           41.0                                13.0
# 4                4.4           44.0                                19.0
# ...              ...            ...                                 ...
# 6544             4.8           48.0                                20.0
# 6545             4.1           41.0                                38.0
# 6546             4.7           47.0                                28.0
# 6547             4.2           42.0                                22.0
# 6548             NaN            NaN                                 NaN
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# ...

# %%
# check if all columns got their name changed
column_list = renamed_df.columns.tolist()

# Display the list of column names
print(column_list)
# Out:
# ['Albumin (g/dL)', 'Albumin (g/L)', 'Alanine aminotransferase ALT (U/L)', 'Aspartate aminotransferase AST (U/L)', 'Alkaline phosphatase (U/L)', 'Blood urea nitrogen (mg/dL)', 'Blood urea nitrogen (mmol/L)', 'Total calcium (mg/dL)', 'Total calcium (mmol/L)', 'Creatine Phosphokinase (CPK) (IU/L)', 'Cholesterol (mg/dL)', 'Cholesterol (mmol/L)', 'Bicarbonate (mmol/L)', 'Creatinine (mg/dL)', 'Creatinine (umol/L)', 'Gamma glutamyl transferase (U/L)', 'Glucose, serum (mg/dL)', 'Glucose, serum (mmol/L)', 'Iron, refrigerated (ug/dL)', 'Iron, refrigerated (umol/L)', 'Lactate Dehydrogenase (U/L)', 'Phosphorus (mg/dL)', 'Phosphorus (mmol/L)', 'Total bilirubin (mg/dL)', 'Total bilirubin (umol/L)', 'Total protein (g/dL)', 'Total protein (g/L)', 'Uric acid (mg/dL)', 'Uric acid (umol/L)', 'Sodium (mmol/L)', 'Potassium (mmol/L)', 'Chloride (mmol/L)', 'Osmolality (mmol/Kg)', 'Globulin (g/dL)', 'Globulin (g/L)', 'Triglycerides (mg/dL)', 'Triglycerides (mmol/L)']

# %%
b = renamed_df.iloc[0:6000, 0:]  # slicing the dataframe to only 6000 rows
b
# Out:
#       Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0                4.8           48.0                                19.0
# 1                4.0           40.0                                13.0
# 2                3.7           37.0                                29.0
# 3                4.1           41.0                                13.0
# 4                4.4           44.0                                19.0
# ...              ...            ...                                 ...
# 5995             4.4           44.0                                50.0
# 5996             4.7           47.0                                17.0
# 5997             4.8           48.0                                24.0
# 5998             NaN            NaN                                 NaN
# 5999             4.2           42.0                                18.0
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# ...

# %%
import numpy as np

# Insert an empty ID column at the beginning
b.insert(0, "ID", np.nan)  # You can use np.nan for an empty column
b
# Out:
#       ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0    NaN             4.8           48.0                                19.0
# 1    NaN             4.0           40.0                                13.0
# 2    NaN             3.7           37.0                                29.0
# 3    NaN             4.1           41.0                                13.0
# 4    NaN             4.4           44.0                                19.0
# ...   ..             ...            ...                                 ...
# 5995 NaN             4.4           44.0                                50.0
# 5996 NaN             4.7           47.0                                17.0
# 5997 NaN             4.8           48.0                                24.0
# 5998 NaN             NaN            NaN                                 NaN
# 5999 NaN             4.2           42.0                                18.0
#
# ...

# %%
# populate the ID column with random IDs that repeat it self at least 6 times
import random

# Determine the number of unique IDs and repetitions
num_ids = len(b) // 6
min_repetitions = 6

# Create a list of unique IDs
unique_ids = list(range(1, num_ids + 1))

# Randomly shuffle the list of unique IDs
random.shuffle(unique_ids)

# Create a list of IDs with at least 6 repetitions each
id_list = [id for id in unique_ids for _ in range(min_repetitions)]

# Add the "ID" column to the DataFrame
b['ID'] = id_list

# Shuffle the DataFrame to randomize the order
b = b.sample(frac=1).reset_index(drop=True)

# %%
b # b is the dataframe with random IDs
# Out:
#        ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0     364             4.4           44.0                                19.0
# 1     966             4.2           42.0                                20.0
# 2      35             4.6           46.0                                28.0
# 3     214             4.5           45.0                                22.0
# 4     205             5.0           50.0                                18.0
# ...   ...             ...            ...                                 ...
# 5995  882             NaN            NaN                                 NaN
# 5996   49             4.5           45.0                                25.0
# 5997  900             4.2           42.0                                24.0
# 5998   86             4.9           49.0                                26.0
# 5999  321             4.2           42.0                                41.0
#
# ...

# %%
# Create a boolean mask for rows where "ID" is equal to 492
mask = b["ID"] == 492

# Use the mask to select the rows
result = b[mask]

# Display the rows with "ID" equal to 492
result
# Out:
#        ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 1467  492             4.1           41.0                                51.0
# 2556  492             4.3           43.0                                16.0
# 2684  492             4.3           43.0                                 9.0
# 2980  492             4.4           44.0                                17.0
# 3837  492             4.3           43.0                                18.0
# 5432  492             4.7           47.0                                29.0
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# 1467                                  36.0                        70.0
# 2556                                  23.0                        55.0
# 2684                                  20.0                        43.0
# 2980                                  28.0                        65.0
# 3837                                  17.0                        49.0
# ...

# %%
# Create a boolean mask for rows where "ID" is equal to 5 
mask = b["ID"] == 5

# Use the mask to select the rows
result = b[mask]

# Display the rows with "ID" equal to 5
result
# Out:
#       ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 193    5             4.3           43.0                                11.0
# 1751   5             4.8           48.0                                34.0
# 3268   5             3.7           37.0                                17.0
# 3396   5             4.4           44.0                                21.0
# 4680   5             4.8           48.0                                16.0
# 5129   5             4.5           45.0                                14.0
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# 193                                   24.0                        76.0
# 1751                                  26.0                        93.0
# 3268                                  15.0                       136.0
# 3396                                  29.0                        69.0
# 4680                                  21.0                        73.0
# ...

# %%
# Remove rows with at least one NaN value
b = b.dropna()

# Reset the index
b.reset_index(drop=True, inplace=True)

# %%
b # dataframe free of nan values
# Out:
#        ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0     364             4.4           44.0                                19.0
# 1     966             4.2           42.0                                20.0
# 2      35             4.6           46.0                                28.0
# 3     214             4.5           45.0                                22.0
# 4     205             5.0           50.0                                18.0
# ...   ...             ...            ...                                 ...
# 5457    7             4.7           47.0                               112.0
# 5458   49             4.5           45.0                                25.0
# 5459  900             4.2           42.0                                24.0
# 5460   86             4.9           49.0                                26.0
# 5461  321             4.2           42.0                                41.0
#
# ...

# %%
#check if ID 5 still has Nan values
# Create a boolean mask for rows where "ID" is equal to 5 
mask = b["ID"] == 5

# Use the mask to select the rows
result = b[mask]

# Display the rows with "ID" equal to 5
result
# Out:
#       ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 172    5             4.3           43.0                                11.0
# 1597   5             4.8           48.0                                34.0
# 2975   5             3.7           37.0                                17.0
# 3090   5             4.4           44.0                                21.0
# 4256   5             4.8           48.0                                16.0
# 4657   5             4.5           45.0                                14.0
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# 172                                   24.0                        76.0
# 1597                                  26.0                        93.0
# 2975                                  15.0                       136.0
# 3090                                  29.0                        69.0
# 4256                                  21.0                        73.0
# ...

# %%
from datetime import datetime, timedelta
b_copy = b.copy()

# Function to generate random dates with a minimum 1-month gap
def generate_dates(num_dates):
    dates = [datetime(2019, 1, 1)]  # Start date
    for _ in range(1, num_dates):
        # Add a random number of days (between 30 and 60 days) to the last date
        next_date = dates[-1] + timedelta(days=random.randint(30, 60))
        dates.append(next_date)
    return dates

# Group the DataFrame by 'ID' and update the "Date" column with generated dates
b_copy ['Date'] = b_copy .groupby('ID')['ID'].transform(lambda x: generate_dates(len(x)))

# Reset the index
b_copy .reset_index(drop=True, inplace=True)

# Display the updated DataFrame
b_copy
# Out:
#        ID  Albumin (g/dL)  Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# 0     364             4.4           44.0                                19.0
# 1     966             4.2           42.0                                20.0
# 2      35             4.6           46.0                                28.0
# 3     214             4.5           45.0                                22.0
# 4     205             5.0           50.0                                18.0
# ...   ...             ...            ...                                 ...
# 5457    7             4.7           47.0                               112.0
# 5458   49             4.5           45.0                                25.0
# 5459  900             4.2           42.0                                24.0
# 5460   86             4.9           49.0                                26.0
# 5461  321             4.2           42.0                                41.0
#
# ...

# %%
# Move 'Date' to the second position while preserving 'ID'
b_copy = b_copy[['ID', 'Date'] + [col for col in b_copy if col not in ['ID', 'Date']]]

b_copy
# Out:
#        ID       Date  Albumin (g/dL)  Albumin (g/L)  \
# 0     364 2019-01-01             4.4           44.0
# 1     966 2019-01-01             4.2           42.0
# 2      35 2019-01-01             4.6           46.0
# 3     214 2019-01-01             4.5           45.0
# 4     205 2019-01-01             5.0           50.0
# ...   ...        ...             ...            ...
# 5457    7 2019-06-22             4.7           47.0
# 5458   49 2019-08-12             4.5           45.0
# 5459  900 2019-06-19             4.2           42.0
# 5460   86 2019-08-10             4.9           49.0
# 5461  321 2019-08-14             4.2           42.0
#
#       Alanine aminotransferase ALT (U/L)  \
# 0                                   19.0
# 1                                   20.0
# 2                                   28.0
# 3                                   22.0
# 4                                   18.0
# ...                                  ...
# 5457                               112.0
# ...

# %%
#check if dates are not all the same for a given ID
# Create a boolean mask for rows where "ID" is equal to 5 
mask = b_copy["ID"] == 5

# Use the mask to select the rows
result = b_copy[mask]

# Display the rows with "ID" equal to 5
result
# Out:
#       ID       Date  Albumin (g/dL)  Albumin (g/L)  \
# 172    5 2019-01-01             4.3           43.0
# 1597   5 2019-02-25             4.8           48.0
# 2975   5 2019-04-24             3.7           37.0
# 3090   5 2019-06-17             4.4           44.0
# 4256   5 2019-07-19             4.8           48.0
# 4657   5 2019-08-21             4.5           45.0
#
#       Alanine aminotransferase ALT (U/L)  \
# 172                                 11.0
# 1597                                34.0
# 2975                                17.0
# 3090                                21.0
# 4256                                16.0
# 4657                                14.0
#
#       Aspartate aminotransferase AST (U/L)  Alkaline phosphatase (U/L)  \
# 172                                   24.0                        76.0
# 1597                                  26.0                        93.0
# 2975                                  15.0                       136.0
# ...

# %%
final_version_blood_tests = b_copy
final_version_blood_tests # it contains 1000 unique IDs, dates from 2019-1-1 to 2019-10-08, and actual code names
# Out:
#        ID       Date  Albumin (g/dL)  Albumin (g/L)  \
# 0     364 2019-01-01             4.4           44.0
# 1     966 2019-01-01             4.2           42.0
# 2      35 2019-01-01             4.6           46.0
# 3     214 2019-01-01             4.5           45.0
# 4     205 2019-01-01             5.0           50.0
# ...   ...        ...             ...            ...
# 5457    7 2019-06-22             4.7           47.0
# 5458   49 2019-08-12             4.5           45.0
# 5459  900 2019-06-19             4.2           42.0
# 5460   86 2019-08-10             4.9           49.0
# 5461  321 2019-08-14             4.2           42.0
#
#       Alanine aminotransferase ALT (U/L)  \
# 0                                   19.0
# 1                                   20.0
# 2                                   28.0
# 3                                   22.0
# 4                                   18.0
# ...                                  ...
# 5457                               112.0
# ...

# %%
final_version_blood_tests.describe()
# Out:
#                 ID                           Date  Albumin (g/dL)  \
# count  5462.000000                           5462     5462.000000
# mean    498.572135  2019-04-13 12:42:58.396191744        4.306280
# min       1.000000            2019-01-01 00:00:00        2.100000
# 25%     246.250000            2019-02-12 00:00:00        4.100000
# 50%     497.000000            2019-04-10 00:00:00        4.300000
# 75%     750.750000            2019-06-11 00:00:00        4.500000
# max    1000.000000            2019-10-08 00:00:00        5.500000
# std     289.619185                            NaN        0.346213
#
#        Albumin (g/L)  Alanine aminotransferase ALT (U/L)  \
# count    5462.000000                         5462.000000
# mean       43.062798                           23.402600
# min        21.000000                            5.000000
# 25%        41.000000                           15.000000
# 50%        43.000000                           19.000000
# ...

# %%
# creating a dataframe with random names for patients

import pandas as pd
patient_data = {
    "ID": [],
    "First Name": [],
    "Last Name": [],
    "Date of Birth": [],
    "Gender": []
}

patients = pd.DataFrame(patient_data)

# %%
patients
# Out:
# Empty DataFrame
# Columns: [ID, First Name, Last Name, Date of Birth, Gender]
# Index: []

# %%
# populating the ID column with 1000 IDs
patients['ID'] = range(1, 1001)
patients
# Out:
#        ID  First Name  Last Name  Date of Birth  Gender
# 0       1         NaN        NaN            NaN     NaN
# 1       2         NaN        NaN            NaN     NaN
# 2       3         NaN        NaN            NaN     NaN
# 3       4         NaN        NaN            NaN     NaN
# 4       5         NaN        NaN            NaN     NaN
# ..    ...         ...        ...            ...     ...
# 995   996         NaN        NaN            NaN     NaN
# 996   997         NaN        NaN            NaN     NaN
# 997   998         NaN        NaN            NaN     NaN
# 998   999         NaN        NaN            NaN     NaN
# 999  1000         NaN        NaN            NaN     NaN
#
# [1000 rows x 5 columns]

# %%
# generating 1000 random names 

import random

first_names = [
    "John", "Jane", "Robert", "Emily", "Michael", "Olivia", "William", "Sophia", "David", "Ava",
    "James", "Mary", "Joseph", "Sarah", "Charles", "Anna", "Thomas", "Mia", "Daniel", "Emma",
    "Richard", "Grace", "Matthew", "Elizabeth", "Andrew", "Lily", "Mark", "Lucas", "Karen", "Jessica",
    "Jennifer", "Benjamin", "Liam", "Lucy", "Aiden", "Chloe", "Joshua", "Daniel", "Sophie", "Grace",
    "Christopher", "Ella", "Nathan", "Oliver", "Victoria", "Alexis", "Isabella", "Charlotte", "Henry", "Madison",
    "Jackson", "Ethan", "Scarlett", "Aria", "Nora", "Liam", "Sophia", "Logan", "Zoe", "Amelia"
]

last_names = [
    "Smith", "Johnson", "Brown", "Jones", "Davis", "Lee", "Wilson", "Harris", "Clark", "Young",
    "Martin", "Thompson", "White", "Anderson", "Walker", "Hall", "Lewis", "Robinson", "Moore", "Taylor",
    "Miller", "Williams", "Wilson", "Harris", "Jackson", "Adams", "Baker", "Carter", "Cooper", "Evans",
    "Garcia", "Hernandez", "King", "Lopez", "Perez", "Phillips", "Scott", "Turner", "Wright", "Green",
    "Davis", "Hall", "Johnson", "Lewis", "Brown", "Martin", "Harris", "Robinson", "Clark", "Moore",
    "Taylor", "White", "Williams", "Anderson", "Lee", "Smith", "Jones", "Young", "Wilson", "Thompson"
]

random_names = []
for _ in range(1000):
    random_name = random.choice(first_names) + " " + random.choice(last_names)
    random_names.append(random_name)

# Print the generated names
for name in random_names:
    print(name)
# Out:
# Grace Carter
# Charlotte Harris
# Charlotte Wilson
# Sophia Lewis
# Elizabeth Adams
# Thomas Thompson
# Isabella Smith
# Scarlett Hernandez
# Logan Carter
# Olivia Martin
# Christopher Clark
# Sarah Green
# Joshua Taylor
# Nora Scott
# Aiden Lopez
# Charlotte Martin
# Sophie Evans
# Ethan Hernandez
# Scarlett Davis
# Richard Brown
# Daniel Williams
# Chloe Miller
# Ella Williams
# Liam Carter
# Anna Green
# Sophia Moore
# Zoe Thompson
# Madison Lewis
# Ava Phillips
# Charles Lee
# Madison Turner
# Robert Davis
# Grace Lee
# Scarlett Martin
# Richard Miller
# Jackson Phillips
# Joseph Hernandez
# Aria Phillips
# Jackson Hall
# Grace Taylor
# Amelia White
# Charlotte Robinson
# William Harris
# Nora Brown
# Isabella Miller
# William Robinson
# Jane Williams
# Nathan Wilson
# Isabella Smith
# Karen Brown
# Anna Lee
# Zoe Martin
# Joseph Anderson
# John Smith
# Jane Brown
# Sophia Moore
# Michael Adams
# Charlotte Brown
# Joseph Lee
# David White
# Sophie Hall
# Liam Thompson
# ...

# %%
#Populating the Name columns with the generated names

random.shuffle(random_names)

# Split the full names into first and last names
first_names, last_names = zip(*(name.split() for name in random_names))

# Populate the "First Name" and "Last Name" columns with random names
patients['First Name'] = [random.choice(first_names) for _ in range(len(patients))]
patients['Last Name'] = [random.choice(last_names) for _ in range(len(patients))]

patients
# Out:
#        ID First Name Last Name  Date of Birth  Gender
# 0       1      Grace    Wright            NaN     NaN
# 1       2       Lily      Hall            NaN     NaN
# 2       3       Jane     Lewis            NaN     NaN
# 3       4      Grace    Garcia            NaN     NaN
# 4       5     Sophie  Williams            NaN     NaN
# ..    ...        ...       ...            ...     ...
# 995   996     Daniel  Williams            NaN     NaN
# 996   997     Robert     Brown            NaN     NaN
# 997   998       Emma    Miller            NaN     NaN
# 998   999      Grace     White            NaN     NaN
# 999  1000     Oliver    Harris            NaN     NaN
#
# [1000 rows x 5 columns]

# %%
# Populating the "Date of Birth" column with random dates 

from datetime import datetime, timedelta

# Populate the "Date of Birth" column with random dates
start_date = datetime(1950, 1, 1)
end_date = datetime(2000, 12, 31)
patients['Date of Birth'] = [start_date + timedelta(days=random.randint(0, (end_date - start_date).days)) for _ in range(len(patients))]


patients
# Out:
#        ID First Name Last Name Date of Birth  Gender
# 0       1      Grace    Wright    1982-08-12     NaN
# 1       2       Lily      Hall    1996-10-19     NaN
# 2       3       Jane     Lewis    1991-09-22     NaN
# 3       4      Grace    Garcia    1972-10-30     NaN
# 4       5     Sophie  Williams    1976-01-28     NaN
# ..    ...        ...       ...           ...     ...
# 995   996     Daniel  Williams    2000-04-08     NaN
# 996   997     Robert     Brown    1976-08-19     NaN
# 997   998       Emma    Miller    1950-06-12     NaN
# 998   999      Grace     White    1951-08-13     NaN
# 999  1000     Oliver    Harris    1961-12-17     NaN
#
# [1000 rows x 5 columns]

# %%
pip install gender_guesser
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show gender_guesser
# Out:
# Name: gender-guesser
# Version: 0.4.0
# Summary: Get the gender from first name.
# Home-page: https://github.com/lead-ratings/gender-guesser
# Author: Israel Saeta Pérez
# Author-email: israel@lead-ratings.com
# License: GPLv3
# Location: /home/rodrigo/repos/DATAVIZ_project/dataviz_venv/lib/python3.10/site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import gender_guesser.detector as gender


# Create a gender detector
d = gender.Detector()

# Function to determine gender based on first name
def assign_gender(name):
    return d.get_gender(name)

# Apply the function to the 'First Name' column and update the 'Gender' column
patients['Gender'] = patients['First Name'].apply(assign_gender)

# Display the updated DataFrame
patients
# Out:
#        ID First Name Last Name Date of Birth  Gender
# 0       1      Grace    Wright    1982-08-12  female
# 1       2       Lily      Hall    1996-10-19  female
# 2       3       Jane     Lewis    1991-09-22  female
# 3       4      Grace    Garcia    1972-10-30  female
# 4       5     Sophie  Williams    1976-01-28  female
# ..    ...        ...       ...           ...     ...
# 995   996     Daniel  Williams    2000-04-08    male
# 996   997     Robert     Brown    1976-08-19    male
# 997   998       Emma    Miller    1950-06-12  female
# 998   999      Grace     White    1951-08-13  female
# 999  1000     Oliver    Harris    1961-12-17    male
#
# [1000 rows x 5 columns]

# %%
# Replace 'mostly_male' with 'male' and 'mostly_female' with 'female'
patients['Gender'] = patients['Gender'].replace({'mostly_male': 'male', 'mostly_female': 'female'})

# Display the updated DataFrame
patients
# Out:
#        ID First Name Last Name Date of Birth  Gender
# 0       1      Grace    Wright    1982-08-12  female
# 1       2       Lily      Hall    1996-10-19  female
# 2       3       Jane     Lewis    1991-09-22  female
# 3       4      Grace    Garcia    1972-10-30  female
# 4       5     Sophie  Williams    1976-01-28  female
# ..    ...        ...       ...           ...     ...
# 995   996     Daniel  Williams    2000-04-08    male
# 996   997     Robert     Brown    1976-08-19    male
# 997   998       Emma    Miller    1950-06-12  female
# 998   999      Grace     White    1951-08-13  female
# 999  1000     Oliver    Harris    1961-12-17    male
#
# [1000 rows x 5 columns]

# %%
# Save the DataFrame to a CSV file (e.g., 'data.csv')
final_version_blood_tests.to_csv('blood_indicators.csv', index=False)  # Set index to False if you don't want to save the row numbers
patients.to_csv('patients.csv', index=False)

# %%
patients
# Out:
#        ID First Name Last Name Date of Birth  Gender
# 0       1      Grace    Wright    1982-08-12  female
# 1       2       Lily      Hall    1996-10-19  female
# 2       3       Jane     Lewis    1991-09-22  female
# 3       4      Grace    Garcia    1972-10-30  female
# 4       5     Sophie  Williams    1976-01-28  female
# ..    ...        ...       ...           ...     ...
# 995   996     Daniel  Williams    2000-04-08    male
# 996   997     Robert     Brown    1976-08-19    male
# 997   998       Emma    Miller    1950-06-12  female
# 998   999      Grace     White    1951-08-13  female
# 999  1000     Oliver    Harris    1961-12-17    male
#
# [1000 rows x 5 columns]

# %%
final_version_blood_tests
# Out:
#        ID       Date  Albumin (g/dL)  Albumin (g/L)  \
# 0     364 2019-01-01             4.4           44.0
# 1     966 2019-01-01             4.2           42.0
# 2      35 2019-01-01             4.6           46.0
# 3     214 2019-01-01             4.5           45.0
# 4     205 2019-01-01             5.0           50.0
# ...   ...        ...             ...            ...
# 5457    7 2019-06-22             4.7           47.0
# 5458   49 2019-08-12             4.5           45.0
# 5459  900 2019-06-19             4.2           42.0
# 5460   86 2019-08-10             4.9           49.0
# 5461  321 2019-08-14             4.2           42.0
#
#       Alanine aminotransferase ALT (U/L)  \
# 0                                   19.0
# 1                                   20.0
# 2                                   28.0
# 3                                   22.0
# 4                                   18.0
# ...                                  ...
# 5457                               112.0
# ...
